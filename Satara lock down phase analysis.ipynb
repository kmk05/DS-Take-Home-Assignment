# %%
import pandas as pd
import shapely.geometry
import shapely.wkt
import geopandas as gpd
from osgeo import gdal
from osgeo import ogr
import json
import numpy as np
import matplotlib.pyplot as plt
from shapely.geometry import Point
from shapely.geometry import Polygon
import math
from osgeo import ogr, gdal
import subprocess
import pandas as pd
import os.path
import shutil
import os.path
import rasterio
import numpy as np
from statistics import mean

# %%
#folder paths 
path_phase1="D:/def downloads/downloads/phase 1"   #phase 1_fold
path_phase2="D:/def downloads/downloads/phase 2"  #phase 2_fold
path_phase3="D:/def downloads/downloads/phase 3"  #phase 3_fold
path_phase4="D:/def downloads/downloads/phase 4"   #phase 4_fold

satara_shp_path="D:/def downloads/downloads/New folder (15)/satara_Output.shp" #satara_shp
workin_dir_path1="D:/def downloads/downloads/New folder (16)"
workin_dir_path2="D:/def downloads/downloads/New folder (17)"
workin_dir_path3="D:/def downloads/downloads/New folder (18)"
workin_dir_path4="D:/def downloads/downloads/New folder (19)"

# %%
#pune_shp info
satara = gpd.read_file(satara_shp_path)
satara_proj=satara.crs

# %%
#open folder for phase1
list_phase1 = []
for x in os.listdir(path_phase1):
    if x.endswith(".tif"):
        x=path_phase1+'/'+x
        list_phase1.append(x)

# %%
list_phase1
# Out:
# ['D:/def downloads/downloads/phase 1/MOD04_L2.A2020085.mosaic.061.2022252082738.pssgrpgs_000501834723.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 1/MOD04_L2.A2020086.mosaic.061.2022252082805.pssgrpgs_000501834723.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 1/MOD04_L2.A2020087.mosaic.061.2022252082808.pssgrpgs_000501834723.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 1/MOD04_L2.A2020088.mosaic.061.2022252082732.pssgrpgs_000501834723.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 1/MOD04_L2.A2020090.mosaic.061.2022252082706.pssgrpgs_000501834723.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 1/MOD04_L2.A2020091.mosaic.061.2022252082611.pssgrpgs_000501834723.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 1/MOD04_L2.A2020092.mosaic.061.2022252082642.pssgrpgs_000501834723.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 1/MOD04_L2.A2020093.mosaic.061.2022252082423.pssgrpgs_000501834723.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 1/MOD04_L2.A2020094.mosaic.061.2022252082812.pssgrpgs_000501834723.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 1/MOD04_L2.A2020095.mosaic.061.2022252082728.pssgrpgs_000501834723.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 1/MOD04_L2.A2020099.mosaic.061.2022252082826.pssgrpgs_000501834723.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 1/MOD04_L2.A2020101.mosaic.061.2022252082708.pssgmcrpgs_000501834723.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 1/MOD04_L2.A2020102.mosaic.061.2022252082827.pssgrpgs_000501834723.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 1/MOD04_L2.A2020103.mosaic.061.2022252082750.pssgrpgs_000501834723.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 1/MOD04_L2.A2020104.mosaic.061.2022252082835.pssgrpgs_000501834723.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif']

# %%
i=0
ph1=[]
for x in range(len(list_phase1)) :
    z=workin_dir_path1+"ph1"+str(i)+"Reprj.tif"
    print(z)
    y1=gdal.Open(list_phase1[i])
    # reproject
    demReprj = gdal.Warp(z, y1 , dstSRS = satara_proj)
    with rasterio.open(z) as src:
        meta = src.meta

        # My target coordinates
        x_coord =74.0183

        y_coord =17.6805

        # Use the transform in the metadata and your coordinates
        rowcol = rasterio.transform.rowcol(meta['transform'], xs=x_coord, ys=y_coord)
        print(rowcol)
        ds = gdal.Open(z)
        y=(y1.GetRasterBand(1).GetNoDataValue())
        print(y)
        arr=np.array(ds.GetRasterBand(1).ReadAsArray())
        arrk= np.where(arr == y, 0,arr)
        arr_1 = np.where(arr<0, 0, arr)
        b=arr_1[rowcol[0]][rowcol[1]]
        print(ph1)
        ph1.append(b)
        i+=1
# ph1.remove(0)
print(ph1)
print(mean(ph1))
avg1 =mean(ph1)
print(max(ph1))
# Out:
# D:/def downloads/downloads/New folder (16)ph10Reprj.tif
# (25, 23)
# None
# []
# D:/def downloads/downloads/New folder (16)ph11Reprj.tif
# (25, 23)
# None
# [571]
# D:/def downloads/downloads/New folder (16)ph12Reprj.tif
# (25, 23)
# None
# [571, 537]
# D:/def downloads/downloads/New folder (16)ph13Reprj.tif
# (25, 23)
# None
# [571, 537, 682]
# D:/def downloads/downloads/New folder (16)ph14Reprj.tif
# (25, 23)
# None
# [571, 537, 682, 435]
# D:/def downloads/downloads/New folder (16)ph15Reprj.tif
# (25, 23)
# None
# [571, 537, 682, 435, 435]
# D:/def downloads/downloads/New folder (16)ph16Reprj.tif
# (25, 23)
# None
# [571, 537, 682, 435, 435, 293]
# D:/def downloads/downloads/New folder (16)ph17Reprj.tif
# (25, 23)
# None
# [571, 537, 682, 435, 435, 293, 534]
# D:/def downloads/downloads/New folder (16)ph18Reprj.tif
# (25, 23)
# None
# [571, 537, 682, 435, 435, 293, 534, 330]
# D:/def downloads/downloads/New folder (16)ph19Reprj.tif
# (25, 23)
# None
# [571, 537, 682, 435, 435, 293, 534, 330, 359]
# D:/def downloads/downloads/New folder (16)ph110Reprj.tif
# (25, 23)
# None
# [571, 537, 682, 435, 435, 293, 534, 330, 359, 461]
# D:/def downloads/downloads/New folder (16)ph111Reprj.tif
# (25, 23)
# None
# [571, 537, 682, 435, 435, 293, 534, 330, 359, 461, 243]
# D:/def downloads/downloads/New folder (16)ph112Reprj.tif
# (25, 23)
# None
# [571, 537, 682, 435, 435, 293, 534, 330, 359, 461, 243, 385]
# D:/def downloads/downloads/New folder (16)ph113Reprj.tif
# (25, 23)
# None
# [571, 537, 682, 435, 435, 293, 534, 330, 359, 461, 243, 385, 382]
# D:/def downloads/downloads/New folder (16)ph114Reprj.tif
# (25, 23)
# None
# [571, 537, 682, 435, 435, 293, 534, 330, 359, 461, 243, 385, 382, 452]
# [571, 537, 682, 435, 435, 293, 534, 330, 359, 461, 243, 385, 382, 452, 662]
# 450
# 682

# %%
#open folder for phase2
list_phase2 = []
for x in os.listdir(path_phase2):
    if x.endswith(".tif"):
        x=path_phase2+'/'+x
        list_phase2.append(x)

# %%
list_phase2
# Out:
# ['D:/def downloads/downloads/phase 2/MOD04_L2.A2020108.mosaic.061.2022252091046.pssgrpgs_000501834737.Deep_Blue_Spectral_Aerosol_Optical_Depth_Land_1-Deep_Blue_Spectral_Aerosol_Optical_Depth_Land.tif',
#  'D:/def downloads/downloads/phase 2/MOD04_L2.A2020108.mosaic.061.2022252091046.pssgrpgs_000501834737.Deep_Blue_Spectral_Aerosol_Optical_Depth_Land_2-Deep_Blue_Spectral_Aerosol_Optical_Depth_Land.tif',
#  'D:/def downloads/downloads/phase 2/MOD04_L2.A2020108.mosaic.061.2022252091046.pssgrpgs_000501834737.Deep_Blue_Spectral_Aerosol_Optical_Depth_Land_3-Deep_Blue_Spectral_Aerosol_Optical_Depth_Land.tif',
#  'D:/def downloads/downloads/phase 2/MOD04_L2.A2020109.mosaic.061.2022252091049.pssgrpgs_000501834737.Deep_Blue_Spectral_Aerosol_Optical_Depth_Land_1-Deep_Blue_Spectral_Aerosol_Optical_Depth_Land.tif',
#  'D:/def downloads/downloads/phase 2/MOD04_L2.A2020109.mosaic.061.2022252091049.pssgrpgs_000501834737.Deep_Blue_Spectral_Aerosol_Optical_Depth_Land_2-Deep_Blue_Spectral_Aerosol_Optical_Depth_Land.tif',
#  'D:/def downloads/downloads/phase 2/MOD04_L2.A2020109.mosaic.061.2022252091049.pssgrpgs_000501834737.Deep_Blue_Spectral_Aerosol_Optical_Depth_Land_3-Deep_Blue_Spectral_Aerosol_Optical_Depth_Land.tif',
#  'D:/def downloads/downloads/phase 2/MOD04_L2.A2020122.mosaic.061.2022252091052.pssgrpgs_000501834737.Deep_Blue_Spectral_Aerosol_Optical_Depth_Land_3-Deep_Blue_Spectral_Aerosol_Optical_Depth_Land.tif',
#  'D:/def downloads/downloads/phase 2/MOD04_L2.A2020124.mosaic.061.2022252091038.pssgrpgs_000501834737.Deep_Blue_Spectral_Aerosol_Optical_Depth_Land_1-Deep_Blue_Spectral_Aerosol_Optical_Depth_Land.tif',
#  'D:/def downloads/downloads/phase 2/MOD04_L2.A2020124.mosaic.061.2022252091038.pssgrpgs_000501834737.Deep_Blue_Spectral_Aerosol_Optical_Depth_Land_2-Deep_Blue_Spectral_Aerosol_Optical_Depth_Land.tif',
#  'D:/def downloads/downloads/phase 2/MOD04_L2.A2020124.mosaic.061.2022252091038.pssgrpgs_000501834737.Deep_Blue_Spectral_Aerosol_Optical_Depth_Land_3-Deep_Blue_Spectral_Aerosol_Optical_Depth_Land.tif']

# %%
i=0
ph2=[]
for x in range(len(list_phase2)) :
    z=workin_dir_path2+"ph2"+str(i)+"Reprj.tif"
    print(z)
    y1=gdal.Open(list_phase2[i])
    print("done")
    # reproject
    demReprj = gdal.Warp(z, y1 , dstSRS = satara_proj)
    with rasterio.open(z) as src:
        meta = src.meta

        # My target coordinates
        x_coord =74.0183

        y_coord =17.6805

        # Use the transform in the metadata and your coordinates
        rowcol = rasterio.transform.rowcol(meta['transform'], xs=x_coord, ys=y_coord)
        print(rowcol)
        ds = gdal.Open(z)
        y=(y1.GetRasterBand(1).GetNoDataValue())
        print(y)
        arr=np.array(ds.GetRasterBand(1).ReadAsArray())
        arrk= np.where(arr == y, 0,arr)
        arr_1 = np.where(arr<0, 0, arr)
        b=arr_1[rowcol[0]][rowcol[1]]
        print(ph2)
        ph2.append(b)
        i+=1
ph2.remove(0)
print(ph2)
print(mean(ph2))
avg2 =mean(ph2)
# Out:
# D:/def downloads/downloads/New folder (17)ph20Reprj.tif
# done
# (25, 23)
# None
# []
# D:/def downloads/downloads/New folder (17)ph21Reprj.tif
# done
# (25, 23)
# None
# [488]
# D:/def downloads/downloads/New folder (17)ph22Reprj.tif
# done
# (25, 23)
# None
# [488, 488]
# D:/def downloads/downloads/New folder (17)ph23Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488]
# D:/def downloads/downloads/New folder (17)ph24Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628]
# D:/def downloads/downloads/New folder (17)ph25Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527]
# D:/def downloads/downloads/New folder (17)ph26Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342]
# D:/def downloads/downloads/New folder (17)ph27Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256]
# D:/def downloads/downloads/New folder (17)ph28Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256]
# D:/def downloads/downloads/New folder (17)ph29Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256]
# D:/def downloads/downloads/New folder (17)ph210Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114]
# D:/def downloads/downloads/New folder (17)ph211Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94]
# D:/def downloads/downloads/New folder (17)ph212Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58]
# D:/def downloads/downloads/New folder (17)ph213Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201]
# D:/def downloads/downloads/New folder (17)ph214Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165]
# D:/def downloads/downloads/New folder (17)ph215Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101]
# D:/def downloads/downloads/New folder (17)ph216Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217]
# D:/def downloads/downloads/New folder (17)ph217Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217]
# D:/def downloads/downloads/New folder (17)ph218Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217, 217]
# D:/def downloads/downloads/New folder (17)ph219Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217, 217, 0]
# D:/def downloads/downloads/New folder (17)ph220Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217, 217, 0, 0]
# D:/def downloads/downloads/New folder (17)ph221Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217, 217, 0, 0, 0]
# D:/def downloads/downloads/New folder (17)ph222Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217, 217, 0, 0, 0, 214]
# D:/def downloads/downloads/New folder (17)ph223Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217, 217, 0, 0, 0, 214, 214]
# D:/def downloads/downloads/New folder (17)ph224Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217, 217, 0, 0, 0, 214, 214, 214]
# D:/def downloads/downloads/New folder (17)ph225Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217, 217, 0, 0, 0, 214, 214, 214, 262]
# D:/def downloads/downloads/New folder (17)ph226Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217, 217, 0, 0, 0, 214, 214, 214, 262, 262]
# D:/def downloads/downloads/New folder (17)ph227Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217, 217, 0, 0, 0, 214, 214, 214, 262, 262, 262]
# D:/def downloads/downloads/New folder (17)ph228Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217, 217, 0, 0, 0, 214, 214, 214, 262, 262, 262, 566]
# D:/def downloads/downloads/New folder (17)ph229Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217, 217, 0, 0, 0, 214, 214, 214, 262, 262, 262, 566, 490]
# D:/def downloads/downloads/New folder (17)ph230Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217, 217, 0, 0, 0, 214, 214, 214, 262, 262, 262, 566, 490, 343]
# D:/def downloads/downloads/New folder (17)ph231Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217, 217, 0, 0, 0, 214, 214, 214, 262, 262, 262, 566, 490, 343, 557]
# D:/def downloads/downloads/New folder (17)ph232Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217, 217, 0, 0, 0, 214, 214, 214, 262, 262, 262, 566, 490, 343, 557, 542]
# D:/def downloads/downloads/New folder (17)ph233Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217, 217, 0, 0, 0, 214, 214, 214, 262, 262, 262, 566, 490, 343, 557, 542, 505]
# D:/def downloads/downloads/New folder (17)ph234Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217, 217, 0, 0, 0, 214, 214, 214, 262, 262, 262, 566, 490, 343, 557, 542, 505, 386]
# D:/def downloads/downloads/New folder (17)ph235Reprj.tif
# done
# (25, 23)
# None
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217, 217, 0, 0, 0, 214, 214, 214, 262, 262, 262, 566, 490, 343, 557, 542, 505, 386, 386]
# [488, 488, 488, 628, 527, 342, 256, 256, 256, 114, 94, 58, 201, 165, 101, 217, 217, 217, 0, 0, 214, 214, 214, 262, 262, 262, 566, 490, 343, 557, 542, 505, 386, 386, 386]
# 305

# %%
#open folder for phase3
list_phase3 = []
for x in os.listdir(path_phase3):
    if x.endswith(".tif"):
        x=path_phase3+'/'+x
        list_phase3.append(x)

# %%
list_phase3
# Out:
# ['D:/def downloads/downloads/phase 3/MOD04_L2.A2020125.mosaic.061.2022252091055.pssgrpgs_000501834747.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 3/MOD04_L2.A2020126.mosaic.061.2022252091059.pssgrpgs_000501834747.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 3/MOD04_L2.A2020127.mosaic.061.2022252091100.pssgrpgs_000501834747.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 3/MOD04_L2.A2020129.mosaic.061.2022252091049.pssgrpgs_000501834747.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 3/MOD04_L2.A2020131.mosaic.061.2022252091053.pssgrpgs_000501834747.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 3/MOD04_L2.A2020133.mosaic.061.2022252091057.pssgrpgs_000501834747.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 3/MOD04_L2.A2020135.mosaic.061.2022252091101.pssgrpgs_000501834747.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif']

# %%
i=0
ph3=[]
for x in range(len(list_phase3)) :
    z=workin_dir_path3+"ph3"+str(i)+"Reprj.tif"
    print(z)
    y1=gdal.Open(list_phase3[i])
    print("done")
    # reproject
    demReprj = gdal.Warp(z, y1 , dstSRS = satara_proj)
    with rasterio.open(z) as src:
        meta = src.meta

        # My target coordinates
        x_coord =74.0183

        y_coord =17.6805

        # Use the transform in the metadata and your coordinates
        rowcol = rasterio.transform.rowcol(meta['transform'], xs=x_coord, ys=y_coord)
        print(rowcol)
        ds = gdal.Open(z)
        y=(y1.GetRasterBand(1).GetNoDataValue())
        print(y)
        arr=np.array(ds.GetRasterBand(1).ReadAsArray())
        arrk= np.where(arr == y, 0,arr)
        arr_1 = np.where(arr<0, 0, arr)
        b=arr_1[rowcol[0]][rowcol[1]]
        print(ph3)
        ph3.append(b)
        i+=1
# ph3.remove(0)
print(ph3)
print(mean(ph3))
avg3 =mean(ph3)
# Out:
# D:/def downloads/downloads/New folder (18)ph30Reprj.tif
# done
# (25, 23)
# None
# []
# D:/def downloads/downloads/New folder (18)ph31Reprj.tif
# done
# (25, 23)
# None
# [294]
# D:/def downloads/downloads/New folder (18)ph32Reprj.tif
# done
# (25, 23)
# None
# [294, 150]
# D:/def downloads/downloads/New folder (18)ph33Reprj.tif
# done
# (25, 23)
# None
# [294, 150, 372]
# D:/def downloads/downloads/New folder (18)ph34Reprj.tif
# done
# (25, 23)
# None
# [294, 150, 372, 227]
# D:/def downloads/downloads/New folder (18)ph35Reprj.tif
# done
# (25, 23)
# None
# [294, 150, 372, 227, 377]
# D:/def downloads/downloads/New folder (18)ph36Reprj.tif
# done
# (25, 23)
# None
# [294, 150, 372, 227, 377, 311]
# [294, 150, 372, 227, 377, 311, 378]
# 301

# %%
#open folder for phase4
list_phase4 = []
for x in os.listdir(path_phase4):
    if x.endswith(".tif"):
        x=path_phase4+'/'+x
        list_phase4.append(x)

# %%
list_phase4
# Out:
# ['D:/def downloads/downloads/phase 4/MOD04_L2.A2020141.mosaic.061.2022252091402.pssgrpgs_000501834763.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 4/MOD04_L2.A2020145.mosaic.061.2022252091409.pssgrpgs_000501834763.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 4/MOD04_L2.A2020147.mosaic.061.2022252091404.pssgrpgs_000501834763.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 4/MOD04_L2.A2020149.mosaic.061.2022252091404.pssgrpgs_000501834763.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif',
#  'D:/def downloads/downloads/phase 4/MOD04_L2.A2020150.mosaic.061.2022252091432.pssgrpgs_000501834763.Deep_Blue_Aerosol_Optical_Depth_550_Land-Deep_Blue_Aerosol_Optical_Depth_550_Land.tif']

# %%
i=0
ph4=[]
for x in range(len(list_phase4)) :
    z=workin_dir_path3+"ph4"+str(i)+"Reprj.tif"
    print(z)
    y1=gdal.Open(list_phase4[i])
    print("done")
    # reproject
    demReprj = gdal.Warp(z, y1 , dstSRS = satara_proj)
    with rasterio.open(z) as src:
        meta = src.meta

        # My target coordinates
        x_coord =74.0183

        y_coord =17.6805

        # Use the transform in the metadata and your coordinates
        rowcol = rasterio.transform.rowcol(meta['transform'], xs=x_coord, ys=y_coord)
        print(rowcol)
        ds = gdal.Open(z)
        y=(y1.GetRasterBand(1).GetNoDataValue())
        print(y)
        arr=np.array(ds.GetRasterBand(1).ReadAsArray())
        arrk= np.where(arr == y, 0,arr)
        arr_1 = np.where(arr<0, 0, arr)
        b=arr_1[rowcol[0]][rowcol[1]]
        print(ph4)
        ph4.append(b)
        i+=1
# ph3.remove(0)
print(ph4)
print(mean(ph4))
avg4 =mean(ph4)
# Out:
# D:/def downloads/downloads/New folder (18)ph40Reprj.tif
# done
# (25, 23)
# None
# []
# D:/def downloads/downloads/New folder (18)ph41Reprj.tif
# done
# (25, 23)
# None
# [139]
# D:/def downloads/downloads/New folder (18)ph42Reprj.tif
# done
# (25, 23)
# None
# [139, 305]
# D:/def downloads/downloads/New folder (18)ph43Reprj.tif
# done
# (25, 23)
# None
# [139, 305, 434]
# D:/def downloads/downloads/New folder (18)ph44Reprj.tif
# done
# (25, 23)
# None
# [139, 305, 434, 67]
# [139, 305, 434, 67, 124]
# 213
